# %% [markdown]
# ### Scrapers for three different formats of NYT articles from the url obtained while using the API

# %%
import pandas as pd
import numpy as np
import requests
from time import sleep
import random 
from bs4 import BeautifulSoup
from collections import defaultdict
import pickle
import re
import math
import time
import os

# %%
df_end = pd.read_csv('end_redo.csv')

# %%
df_end
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0              0             0           15000             15000
# 1              1             1           15001             15001
# 2              2             2           15002             15002
# 3              3             3           15003             15003
# 4              4             4           15004             15004
# 5              5             5           15005             15005
# 6              6             6           15006             15006
# 7              7             7           15007             15007
# 8              8             8           15008             15008
# 9              9             9           15009             15009
# 10            10            10           15010             15010
# 11            11            11           15011             15011
# 12            12            12           15012             15012
# ...

# %%
df_end[df_end['article'].str.len()==2].count()
# Out:
# Unnamed: 0            0
# Unnamed: 0.1          0
# Unnamed: 0.1.1        0
# Unnamed: 0.1.1.1      0
# Unnamed: 0.1.1.1.1    0
# date                  0
# headline              0
# id                    0
# score                 0
# snippet               0
# source                0
# type                  0
# url                   0
# word_count            0
# article               0
# dtype: int64

# %%
alternate2_scrape_from_url(df['url'].iloc[6251])
# Out:
# https://www.nytimes.com/video/us/politics/100000005833630/where-does-trumps-border-wall-stand-today.html
# <Response [200]>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-68adf52e4d07> in <module>()
# ----> 1 alternate2_scrape_from_url(df['url'].iloc[6251])
#
# <ipython-input-20-7d986af4a3a9> in alternate2_scrape_from_url(url)
#       5     soup = BeautifulSoup(r.text, 'html.parser')
#       6
# ----> 7     section = soup.find('p',{"class":'story-body-text'}).parent
#       8     results = section.find_all('li')
#       9     article = []
#
# AttributeError: 'NoneType' object has no attribute 'parent'

# %%
def scrape_from_url(url):

    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    results = soup.find_all('p', attrs={'class':"story-body-text story-content"})
    #print(results)
    article = []
    for r in results:
        article.append(r.text)
    return article

# %%
df_end.loc[df_end.article.str.len()==2,'article'] = df_end.loc[df_end.article.str.len()==2,'url'].apply(alternate_scrape_from_url)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
df_end.to_csv('end_redo.csv')

# %%
def alternate_scrape_from_url(url):

    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    results = soup.find_all('p', attrs={'class':"css-c65vdd e2kc3sl0"})
    print(r)
    article = []
    for r in results:
        article.append(r.text)
    return article

# %%
alternate_scrape_from_url(df['url'].iloc[6363])

# %%
def alternate2_scrape_from_url(url):
    print(url)
    r = requests.get(url)
    print(r)
    soup = BeautifulSoup(r.text, 'html.parser')

    section = soup.find('p',{"class":'story-body-text'}).parent
    results = section.find_all('li')
    article = []
    for r in results:
        article.append(r.text)
    return article

# %%
alternate_scrape_from_url(df_end['url'].iloc[6512])

# %%
df_redo = pd.read_csv('end_redo.csv')

# %%
df_redo[['article', 'date']]
# Out:
#                                                 article        date
# 0     ['The opponents of immigration reform have man...  2013-05-07
# 1                                                    []  2013-05-08
# 2     ['WASHINGTON — Senator Marco Rubio, Republican...  2013-05-08
# 3                                                    []  2013-05-08
# 4                                                    []  2013-05-08
# 5                                                    []  2013-05-08
# 6     ['WASHINGTON — The turnout rate of black voter...  2013-05-09
# 7     ['TIJUANA, Mexico — Erik García arrived at the...  2013-05-08
# 8     ['DENVER — In one of their final acts before w...  2013-05-09
# 9     ['WASHINGTON — The revelation that a co-author...  2013-05-09
# 10                                                   []  2013-05-08
# 11                                                   []  2013-05-09
# 12    ['Many on the political right simply can’t get...  2013-05-09
# ...
